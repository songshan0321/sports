# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # Train Soccer Player Detector
#
# ---
#
# [![Download Dataset](https://app.roboflow.com/images/download-dataset-badge.svg)](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc)
#
# This notebook is based on the [How to Train YOLOv8 Object Detection on a Custom Dataset](https://github.com/roboflow/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb) notebook from the [roboflow/notebooks](https://github.com/roboflow/notebooks) repository.

# %% [markdown]
# ## Configure API keys
#
# - Open your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Fri Jan  3 21:34:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.58.02              Driver Version: 555.58.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...    Off |   00000000:01:00.0  On |                  N/A |
# |  0%   43C    P3             27W /  295W |     879MiB /  16376MiB |      6%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2826      G   /usr/lib/xorg/Xorg                            278MiB |
# |    0   N/A  N/A      3100      G   /usr/bin/gnome-shell                           37MiB |
# |    0   N/A  N/A      3699      G   /usr/libexec/xdg-desktop-portal-gnome          33MiB |
# |    0   N/A  N/A      4345      G   ...seed-version=20241225-174432.450000         97MiB |
# |    0   N/A  N/A      5018      G   /usr/bin/nautilus                             114MiB |
# |    0   N/A  N/A      5098      G   ...erProcess --variations-seed-version        138MiB |
# |    0   N/A  N/A    413715      G   /usr/bin/gnome-text-editor                     14MiB |
# |    0   N/A  N/A   3667174      G   /snap/vlc/3777/usr/bin/vlc                     70MiB |
# |    0   N/A  N/A   3668248      G   ...nglingPtr --variations-seed-version         37MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/shan/proj/sports/examples/soccer/notebooks

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q ultralytics==8.0.196 roboflow python-dotenv
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Imports

# %%
from roboflow import Roboflow
from dotenv import load_dotenv
from IPython.display import Image

# %% [markdown]
# ## Pull dataset

# %%
import os

load_dotenv()

# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

ROBOFLOW_API_KEY = os.getenv("ROBOFLOW_API_KEY")
rf = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘/home/shan/proj/sports/examples/soccer/notebooks/datasets’: File exists
# /home/shan/proj/sports/examples/soccer/notebooks/datasets
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# **NOTE:** Update `data.yaml` structure to align with the latest requirements of the `ultralytics` package.

# %%
# !sed -i 's|\(train: \).*|\1../train/images|' {dataset.location}/data.yaml
# !sed -i 's|\(val: \).*|\1../valid/images|' {dataset.location}/data.yaml

# %% [markdown]
# ## Custom training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml batch=4 epochs=400 imgsz=1280 plots=True
# Out:
# /home/shan/proj/sports/examples/soccer/notebooks
# /home/shan/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/ultralytics/nn/tasks.py:567: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load
# New https://pypi.org/project/ultralytics/8.3.57 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 15973MiB)
# engine/trainer: task=detect, mode=train, model=yolov8x.pt, data=/home/shan/proj/sports/examples/soccer/notebooks/datasets/football-players-detection-10/data.yaml, epochs=200, patience=50, batch=4, imgsz=1280, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=/home/shan/proj/sports/runs/detect/train3
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8721820  ultralytics.nn.modules.head.Detect           [4, [320, 640, 640]]
# Model summary: 365 layers, 68156460 parameters, 68156444 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /home/shan/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/ultralytics/nn/tasks.py:567: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load
# /home/shan/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/ultralytics/utils/checks.py:558: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(True):
# AMP: checks passed ✅
# /home/shan/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/ultralytics/engine/trainer.py:238: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = amp.GradScaler(enabled=self.amp)
# train: Scanning /home/shan/proj/sports/examples/soccer/notebooks/datasets/footba
# val: Scanning /home/shan/proj/sports/examples/soccer/notebooks/datasets/football
# Plotting labels to /home/shan/proj/sports/runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 4 dataloader workers
# Logging results to /home/shan/proj/sports/runs/detect/train3
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      12.6G     0.8484      1.249      0.855         77       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.134      0.553     0.0923     0.0547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      12.9G     0.8961     0.8563     0.8589        102       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025     0.0473       0.23      0.032     0.0209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      13.1G      1.019     0.7251     0.8702         79       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025     0.0473       0.23      0.032     0.0209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      12.9G     0.9948      1.095     0.8806        158       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.134     0.0932     0.0818     0.0463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      13.1G      1.124      1.153     0.8965         54       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.106      0.275      0.079     0.0428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      12.8G      1.003     0.8584     0.8855        131       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.499      0.535      0.466      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      12.9G     0.9689     0.7752     0.8812         77       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.489      0.422      0.405       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      13.1G     0.9792     0.6834     0.8881        136       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.656      0.572      0.578      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      12.6G     0.8495     0.6496     0.8586         31       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.695      0.563      0.587      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      12.8G     0.8609     0.5983      0.852         96       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.882      0.644       0.71      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      12.9G     0.8577      0.558     0.8507        107       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.813      0.696      0.767      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200        13G     0.8322     0.5145     0.8415         69       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.942      0.726      0.827      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200        13G     0.8203     0.4902     0.8483         83       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.718      0.677      0.738      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200        13G     0.8478     0.4968     0.8473         48       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.903       0.71      0.808      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      12.6G     0.9039     0.5383     0.8469        176       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.798      0.736      0.817      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      12.9G     0.7992     0.5201     0.8427         88       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025       0.87      0.747      0.809      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      13.1G     0.7879     0.4894     0.8422         37       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.811      0.681      0.745      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      13.1G     0.7976     0.4875     0.8353         95       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0
1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.925      0.828      0.887      0.662
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     191/200        13G     0.4548     0.2298     0.7813         50       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.902      0.832      0.875      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     192/200        13G     0.4646      0.233      0.781         46       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.898       0.84      0.871      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     193/200        13G     0.4562     0.2264     0.7836         47       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.938      0.816      0.874       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     194/200        13G     0.4449     0.2222     0.7815         45       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.933      0.821      0.877      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     195/200        13G     0.4472     0.2227     0.7813         47       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.932      0.822      0.876      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     196/200        13G     0.4451     0.2227      0.784         46       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.946      0.827      0.879      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     197/200      13.1G     0.4446     0.2221     0.7792         48       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.931      0.821      0.879      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     198/200        13G     0.4378     0.2196     0.7821         47       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.931      0.816       0.88      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     199/200        13G     0.4376     0.2204     0.7824         46       1280: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.948      0.813       0.88      0.659
# Stopping training early as no improvement observed in last 50 epochs. Best results observed at epoch 149, best model saved as best.pt.
# To update EarlyStopping(patience=50) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 199 epochs completed in 1.498 hours.
# Optimizer stripped from /home/shan/proj/sports/runs/detect/train3/weights/last.pt, 136.8MB
# Optimizer stripped from /home/shan/proj/sports/runs/detect/train3/weights/best.pt, 136.8MB
#
# Validating /home/shan/proj/sports/runs/detect/train3/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 15973MiB)
# Model summary (fused): 268 layers, 68127420 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.902      0.872      0.888      0.669
#                   ball         43         39      0.883       0.59      0.646      0.353
#             goalkeeper         43         32      0.856      0.928      0.924      0.745
#                 player         43        853      0.958      0.988      0.994      0.848
#                referee         43        101       0.91       0.98      0.987       0.73
# Speed: 0.2ms preprocess, 16.0ms inference, 0.0ms loss, 9.2ms postprocess per image
# Results saved to /home/shan/proj/sports/runs/detect/train3
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
HOME = os.getcwd()
print(HOME)

# !ls {HOME}/runs/detect/train3/
# Out:
# /home
# ls: cannot access '/home/runs/detect/train3/': No such file or directory

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /home/shan/proj/sports

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/results.png', width=600)
# Out:
# /home
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 get_ipython().run_line_magic('cd', '{HOME}')
# ----> 2 Image(filename=f'{HOME}/runs/detect/train3/results.png', width=600)
#
# File ~/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/IPython/core/display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File ~/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/IPython/core/display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File ~/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/IPython/core/display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File ~/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/IPython/core/display.py:353, in DisplayObject.reload(self)
#     351 if self.filename is not None:
#     352     encoding = None if "b" in self._read_flags else "utf-8"
# --> 353     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     354         self.data = f.read()
#     355 elif self.url is not None:
#     356     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/runs/detect/train3/results.png'

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/val_batch0_pred.jpg', width=600)
# Out:
# /home/shan/proj/sports

# %% [markdown]
# ## Validate custom model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml imgsz=1280
# Out:
# /home/shan/proj/sports
# /home/shan/proj/sports/examples/soccer/notebooks/venv/lib/python3.8/site-packages/ultralytics/nn/tasks.py:567: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 15973MiB)
# Model summary (fused): 268 layers, 68127420 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /home/shan/proj/sports/examples/soccer/notebooks/datasets/football
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.914      0.835      0.874      0.676
#                   ball         43         39      0.866      0.487      0.593      0.335
#             goalkeeper         43         32      0.906      0.904      0.926      0.784
#                 player         43        853      0.958      0.989      0.994      0.866
#                referee         43        101      0.926       0.96      0.984      0.721
# Speed: 2.0ms preprocess, 30.2ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /home/shan/proj/sports/runs/detect/val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Deploy model on Roboflow

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# An error occured when getting the model upload URL: 404 Client Error: Not Found for url: https://api.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/10/uploadModel?api_key=qlsh7ovL6p10ciT0pALM&modelType=yolov8&nocache=true
